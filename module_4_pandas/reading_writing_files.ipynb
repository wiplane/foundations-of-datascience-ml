# %% [markdown]
# # Learning Objectives
#
# 1. Reading a CSV file
# 2. Reading a raw file from GitHub link
# 3. Reading an Excel file
# 4. Writing a dataframe file to a local directory

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading a CSV file

# %%
movies_df = pd.read_csv("../data/movies.csv", sep=',')
movies_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_df.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
movies_df.tail(10)
# Out:
#       budget                                             genres  \
# 4793       0                      [{"id": 18, "name": "Drama"}]
# 4794       0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4796    7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# ...

# %%
movies_df.sample(5)
# Out:
#         budget                                             genres  \
# 2622  15000000                   [{"id": 53, "name": "Thriller"}]
# 2541  15000000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 2275  27220000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4170   1800000  [{"id": 27, "name": "Horror"}, {"id": 18, "nam...
# 4612    300000                      [{"id": 18, "name": "Drama"}]
#
#                              homepage      id  \
# 2622  http://in-crowd.warnerbros.com/   36047
# 2541                              NaN    9276
# 2275                              NaN  199373
# 4170      http://thelastexorcism.com/   38358
# 4612                              NaN   26518
#
#                                                keywords original_language  \
# 2622         [{"id": 187056, "name": "woman director"}]                en
# 2541  [{"id": 579, "name": "american football"}, {"i...                en
# ...

# %% [markdown]
# ## Reading excel files

# %%
emp_df = pd.read_excel("../data/employee.xlsx")

# %%
emp_df
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      100       Steven        King 2003-06-17
# 1      101        Neena     Kochhar 2005-09-21
# 2      102          Lex     De Haan 2001-01-13
# 3      103    Alexander      Hunold 2006-01-03
# 4      104        Bruce       Ernst 2007-05-21
# 5      105        David      Austin 2005-06-25
# 6      106        Valli   Pataballa 2006-02-05
# 7      107        Diana     Lorentz 2007-02-07
# 8      108        Nancy   Greenberg 2002-08-17
# 9      109       Daniel      Faviet 2002-08-16
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 12     112  Jose Manuel       Urman 2006-03-07
# 13     113         Luis        Popp 2007-12-07
# 14     114          Den    Raphaely 2002-12-07
# 15     115    Alexander        Khoo 2003-05-18
# 16     116       Shelli       Baida 2005-12-24
# 17     117        Sigal      Tobias 2005-07-24
# 18     118          Guy      Himuro 2006-11-15
# ...

# %%
movies_df.to_csv("../data/sample_movies_test.csv", index=False)
